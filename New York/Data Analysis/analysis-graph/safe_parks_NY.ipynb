# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_park = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/parks/safe_park.csv', header=None)
data_park_bronx = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/parks/safe_park_bronx.csv', header=None)
data_park_brooklyn = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/parks/safe_park_brooklyn.csv', header=None)
data_park_manhattan = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/parks/safe_park_manhattan.csv', header=None)
data_park_queens = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/parks/safe_park_queens.csv', header=None)
data_park_staten = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/parks/safe_park_staten.csv', header=None)

# %%
#safe park
plt.bar(range(len(data_park[0])), data_park[1])
plt.xticks(range(len(data_park[0])), data_park[0], rotation=90)
plt.xlabel("Park Name")
plt.ylabel("Crimes")
plt.title("Safe park in NY")
plt.show()

# %%
#safe park in bronx
plt.bar(range(len(data_park_bronx[0])), data_park_bronx[1])
plt.xticks(range(len(data_park_bronx[0])), data_park_bronx[0], rotation=90)
plt.xlabel("Park Name")
plt.ylabel("Crimes")
plt.title("Safe park in Bronx")
plt.show()

# %%
#safe park in brooklyn
plt.bar(range(len(data_park_brooklyn[0])), data_park_brooklyn[1])
plt.xticks(range(len(data_park_brooklyn[0])), data_park_brooklyn[0], rotation=90)
plt.xlabel("Park Name")
plt.ylabel("Crimes")
plt.title("Safe park in Brooklyn")
plt.show()

# %%
#safe park in manhattan
plt.bar(range(len(data_park_manhattan[0])), data_park_manhattan[1])
plt.xticks(range(len(data_park_manhattan[0])), data_park_manhattan[0], rotation=90)
plt.xlabel("Park Name")
plt.ylabel("Crimes")
plt.title("Safe park in Manhattan")
plt.show()

# %%
#safe park in queens
plt.bar(range(len(data_park_queens[0])), data_park_queens[1])
plt.xticks(range(len(data_park_queens[0])), data_park_queens[0], rotation=90)
plt.xlabel("Park Name")
plt.ylabel("Crimes")
plt.title("Safe park in Queens")
plt.show()

# %%
#safe park in staten
plt.bar(range(len(data_park_staten[0])), data_park_staten[1])
plt.xticks(range(len(data_park_staten[0])), data_park_staten[0], rotation=90)
plt.xlabel("Park Name")
plt.ylabel("Crimes")
plt.title("Safe park in Staten")
plt.show()

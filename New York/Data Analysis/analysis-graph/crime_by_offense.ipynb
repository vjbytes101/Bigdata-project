# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data_y1 = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/crime_by_offese/crime_by_ofns_year1.csv', header=None)
data_y2 = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/crime_by_offese/crime_by_ofns_year2.csv', header=None)
data_y3 = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/crime_by_offese/crime_by_ofns_year3.csv', header=None)
data_y4 = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/crime_by_offese/crime_by_ofns_year4.csv', header=None)
data_y5 = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/crime_by_offese/crime_by_ofns_year5.csv', header=None)
data_all = [data_y1,data_y2,data_y3,data_y4,data_y5]

# %%
for i in range(0,5):
    plt.plot(data_all[i][0], data_all[i][1], label=data_all[i][2][0])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel("Year")
plt.ylabel("Crimes")
plt.title("Top 5 Offenses over the years")
plt.show()

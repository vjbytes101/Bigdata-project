# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_crtype = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/juris crime/crime_by_juris.csv', header=None)
data_crtype_bronx = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/juris crime/crime_by_juris_bronx.csv', header=None)
data_crtype_brooklyn = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/juris crime/crime_by_juris_brooklyn.csv', header=None)
data_crtype_manhattan = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/juris crime/crime_by_juris_manhattan.csv', header=None)
data_crtype_queens = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/juris crime/crime_by_juris_queens.csv', header=None)
data_crtype_staten = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/juris crime/crime_by_juris_staten.csv', header=None)

# %%
plt.bar(range(len(data_crtype[0])), data_crtype[1])
plt.xticks(range(len(data_crtype[0])), data_crtype[0], rotation=90)
plt.xlabel("Jurisdiction")
plt.ylabel("Crimes")
plt.title("Crimes Jurisdiction")
plt.show()

# %%
#crime juris by bronx
plt.bar(range(len(data_crtype_bronx[0])), data_crtype_bronx[1])
plt.xticks(range(len(data_crtype_bronx[0])), data_crtype_bronx[0], rotation=90)
plt.xlabel("Jurisdiction")
plt.ylabel("Crimes")
plt.title("Crimes Jurisdiction in Bronx")
plt.show()

# %%
#crime juris by brooklyn
plt.bar(range(len(data_crtype_brooklyn[0])), data_crtype_brooklyn[1])
plt.xticks(range(len(data_crtype_brooklyn[0])), data_crtype_brooklyn[0], rotation=90)
plt.xlabel("Jurisdiction")
plt.ylabel("Crimes")
plt.title("Crimes Jurisdiction in Brooklyn")
plt.show()

# %%
#crime juris by manhattan
plt.bar(range(len(data_crtype_manhattan[0])), data_crtype_manhattan[1])
plt.xticks(range(len(data_crtype_manhattan[0])), data_crtype_manhattan[0], rotation=90)
plt.xlabel("Jurisdiction")
plt.ylabel("Crimes")
plt.title("Crimes Jurisdiction in Manhattan")
plt.show()

# %%
#crime juris by queens
plt.bar(range(len(data_crtype_queens[0])), data_crtype_queens[1])
plt.xticks(range(len(data_crtype_queens[0])), data_crtype_queens[0], rotation=90)
plt.xlabel("Jurisdiction")
plt.ylabel("Crimes")
plt.title("Crimes Jurisdiction in Queens")
plt.show()

# %%
#crime juris by staten
plt.bar(range(len(data_crtype_staten[0])), data_crtype_staten[1])
plt.xticks(range(len(data_crtype_staten[0])), data_crtype_staten[0], rotation=90)
plt.xlabel("Jurisdiction")
plt.ylabel("Crimes")
plt.title("Crimes Jurisdiction in Staten Island")
plt.show()

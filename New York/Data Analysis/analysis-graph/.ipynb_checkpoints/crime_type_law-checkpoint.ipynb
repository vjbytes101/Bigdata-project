# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_crtype = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/crime_law_cd/crime_by_law_cd.csv', header=None)
data_crtype_bronx = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/crime_law_cd/crime_by_law_cd_bronx.csv', header=None)
data_crtype_brooklyn = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/crime_law_cd/crime_by_law_cd_brooklyn.csv', header=None)
data_crtype_manhattan = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/crime_law_cd/crime_by_law_cd_manhattan.csv', header=None)
data_crtype_queens = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/crime_law_cd/crime_by_law_cd_queens.csv', header=None)
data_crtype_staten = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/crime_law_cd/crime_by_law_cd_staten.csv', header=None)

# %%
plt.bar(data_crtype[0], data_crtype[1], color='red')
plt.xlabel("Crime Type")
plt.ylabel("Crimes")
plt.title("Crimes Type")
plt.show()

# %%
#crime type by bronx
plt.bar(data_crtype_bronx[0], data_crtype_bronx[1], color='red')
plt.xlabel("Crime Type")
plt.ylabel("Crimes")
plt.title("Crimes Type in Bronx")
plt.show()

# %%
#crime type by brooklyn
plt.bar(data_crtype_brooklyn[0], data_crtype_brooklyn[1], color='red')
plt.xlabel("Crime Type")
plt.ylabel("Crimes")
plt.title("Crimes Type in Brooklyn")
plt.show()

# %%
#crime type by manhattan
plt.bar(data_crtype_manhattan[0], data_crtype_manhattan[1], color='red')
plt.xlabel("Crime Type")
plt.ylabel("Crimes")
plt.title("Crimes Type in Manhattan")
plt.show()

# %%
#crime type by queens
plt.bar(data_crtype_queens[0], data_crtype_queens[1], color='red')
plt.xlabel("Crime Type")
plt.ylabel("Crimes")
plt.title("Crimes Type in Queens")
plt.show()

# %%
#crime type by staten
plt.bar(data_crtype_staten[0], data_crtype_staten[1], color='red')
plt.xlabel("Crime Type")
plt.ylabel("Crimes")
plt.title("Crimes Type in Staten Island")
plt.show()

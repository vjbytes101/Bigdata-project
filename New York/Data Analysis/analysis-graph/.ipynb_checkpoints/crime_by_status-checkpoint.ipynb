# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_loc = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/crm_at_ct crime/crime_by_crm_atpt.csv', header=None)

# %%
plt.bar(data_loc[0], data_loc[1], color='blue')
plt.xlabel("Status")
plt.ylabel("Crimes")
plt.title("Crimes by Status")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data_month = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/Monthly distribution of crimes/crime_by_month.csv', header=None)
data_month_bronx = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/Monthly distribution of crimes/crime_by_month_bronx.csv', header=None)
data_month_brooklyn = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/Monthly distribution of crimes/crime_by_month_brooklyn.csv', header=None)
data_month_manhattan = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/Monthly distribution of crimes/crime_by_month_manhattan.csv', header=None)
data_month_queens = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/Monthly distribution of crimes/crime_by_month_queens.csv', header=None)
data_month_staten = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/Monthly distribution of crimes/crime_by_month_staten.csv', header=None)

# %%
#crime by month
plt.plot(data_month[0], data_month[1], "r--", marker=".")
plt.xlabel("Months")
plt.ylabel("Crimes")
plt.title("Crimes by Months")
plt.show()

# %%
#crime by month bronx
plt.plot(data_month_bronx[0], data_month_bronx[1], "r--", marker=".")
plt.xlabel("Months")
plt.ylabel("Crimes")
plt.title("Crimes by Months in Bronx")
plt.show()

# %%
#crime by month Brooklyn
plt.plot(data_month_brooklyn[0], data_month_brooklyn[1], "r--", marker=".")
plt.xlabel("Months")
plt.ylabel("Crimes")
plt.title("Crimes by Months in Brooklyn")
plt.show()

# %%
#crime by month Manhattan
plt.plot(data_month_manhattan[0], data_month_manhattan[1], "r--", marker=".")
plt.xlabel("Months")
plt.ylabel("Crimes")
plt.title("Crimes by Months in Manhattan")
plt.show()

# %%
#crime by month Queens
plt.plot(data_month_queens[0], data_month_queens[1], "r--", marker=".")
plt.xlabel("Months")
plt.ylabel("Crimes")
plt.title("Crimes by Months in Queens")
plt.show()

# %%
#crime by month Staten
plt.plot(data_month_staten[0], data_month_staten[1], "r--", marker=".")
plt.xlabel("Months")
plt.ylabel("Crimes")
plt.title("Crimes by Months in Staten")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_all = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/crime_type/crime_by_type.csv', header=None)
data_bronx = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/crime_type/crime_by_type_bronx.csv', header=None)
data_brooklyn = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/crime_type/crime_by_type_brooklyn.csv', header=None)
data_manhattan = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/crime_type/crime_by_type_manhattan.csv', header=None)
data_queens = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/crime_type/crime_by_type_queens.csv', header=None)
data_staten = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/crime_type/crime_by_type_staten.csv', header=None)

# %%
#crime type by NY
plt.bar(range(len(data_all[0])), data_all[1])
plt.xticks(range(len(data_all[0])), data_all[0], rotation=90)
plt.xlabel("Crime Type")
plt.ylabel("Number of Crimes")
plt.title("Highest Frequency crime of NY")
plt.show()

# %%
#crime type by Bronx
plt.bar(range(len(data_bronx[0])), data_bronx[1])
plt.xticks(range(len(data_bronx[0])), data_bronx[0], rotation=90)
plt.xlabel("Crime Type")
plt.ylabel("Number of Crimes")
plt.title("Highest Frequency crime of Bronx")
plt.show()

# %%
#crime type by Brooklyn
plt.bar(range(len(data_brooklyn[0])), data_brooklyn[1])
plt.xticks(range(len(data_brooklyn[0])), data_brooklyn[0], rotation=90)
plt.xlabel("Crime Type")
plt.ylabel("Number of Crimes")
plt.title("Highest Frequency crime of Brooklyn")
plt.show()

# %%
#crime type by Manhattan
plt.bar(range(len(data_manhattan[0])), data_manhattan[1])
plt.xticks(range(len(data_manhattan[0])), data_manhattan[0], rotation=90)
plt.xlabel("Crime Type")
plt.ylabel("Number of Crimes")
plt.title("Highest Frequency crime of Manhattan")
plt.show()

# %%
#crime type by Queens
plt.bar(range(len(data_queens[0])), data_queens[1])
plt.xticks(range(len(data_queens[0])), data_queens[0], rotation=90)
plt.xlabel("Crime Type")
plt.ylabel("Number of Crimes")
plt.title("Highest Frequency crime of Queens")
plt.show()

# %%
#crime type by Staten
plt.bar(range(len(data_staten[0])), data_staten[1])
plt.xticks(range(len(data_staten[0])), data_staten[0], rotation=90)
plt.xlabel("Crime Type")
plt.ylabel("Number of Crimes")
plt.title("Highest Frequency crime of Staten Island")
plt.show()

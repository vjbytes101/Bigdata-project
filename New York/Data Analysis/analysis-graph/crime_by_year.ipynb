# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data_year = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/Yearly distribution of crimes/crime_by_year.csv', header=None)
data_year_bronx = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/Yearly distribution of crimes/crime_by_year_bronx.csv', header=None)
data_year_brooklyn = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/Yearly distribution of crimes/crime_by_year_brooklyn.csv', header=None)
data_year_manhattan = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/Yearly distribution of crimes/crime_by_year_manhattan.csv', header=None)
data_year_queens = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/Yearly distribution of crimes/crime_by_year_queens.csv', header=None)
data_year_staten = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/Yearly distribution of crimes/crime_by_year_staten.csv', header=None)

# %%
plt.plot(data_year[0], data_year[1], "r--", marker=".")
plt.xlabel("Year")
plt.ylabel("Crimes")
plt.title("Crimes by Year")
plt.show()

# %%
#crime by year in Bronx
plt.plot(data_year_bronx[0], data_year_bronx[1], "r--", marker=".")
plt.xlabel("Year")
plt.ylabel("Crimes")
plt.title("Crimes by Year in Bronx")
plt.show()

# %%
#crime by year in Brooklyn
plt.plot(data_year_brooklyn[0], data_year_brooklyn[1], "r--", marker=".")
plt.xlabel("Year")
plt.ylabel("Crimes")
plt.title("Crimes by Year in Brooklyn")
plt.show()

# %%
#crime by year in Manhattan
plt.plot(data_year_manhattan[0], data_year_manhattan[1], "r--", marker=".")
plt.xlabel("Year")
plt.ylabel("Crimes")
plt.title("Crimes by Year in Manhattan")
plt.show()

# %%
#crime by year in Queens
plt.plot(data_year_queens[0], data_year_queens[1], "r--", marker=".")
plt.xlabel("Year")
plt.ylabel("Crimes")
plt.title("Crimes by Year in Queens")
plt.show()

# %%
#crime by year in Staten
plt.plot(data_year_staten[0], data_year_staten[1], "r--", marker=".")
plt.xlabel("Year")
plt.ylabel("Crimes")
plt.title("Crimes by Year in Staten")
plt.show()

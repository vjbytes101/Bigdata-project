# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/crime_by_boro/crime_by_boro.csv', header=None)

# %%
#crime by boro
plt.bar(range(len(data[0])), data[1])
plt.xticks(range(len(data[0])), data[0], rotation=90)
plt.xlabel("Boro")
plt.ylabel("Number of Crimes")
plt.title("Crimes by Boro's")
plt.show()

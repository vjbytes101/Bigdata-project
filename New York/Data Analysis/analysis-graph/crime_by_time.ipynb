# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/crime_by_time/crimebytime.csv', header=None)

# %%
plt.bar(data[0], data[1], color='red')
plt.xlabel("Time of Day")
plt.ylabel("Crimes")
plt.title("Crimes by Time during Day")
plt.show()

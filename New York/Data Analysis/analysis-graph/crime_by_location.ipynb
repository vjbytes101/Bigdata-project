# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_loc = pd.read_csv('C:/Users/Vijay/Desktop/Sem2/big data project/Data Analysis/location/crime_location.csv', header=None)

# %%
plt.bar(data_loc[0], data_loc[1], color='blue')
plt.xlabel("Location")
plt.ylabel("Crimes")
plt.title("Crimes by location")
plt.show()
